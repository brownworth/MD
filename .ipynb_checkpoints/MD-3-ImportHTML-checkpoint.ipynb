# %% [markdown]
# Using Pandas and Numpy with Data
# --

# %% [markdown]
# First, we'll need to import the libraries.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# This is an example of how to read a table from Wikipedia, harvest some data, and change it around so that it reads well for NumPy and Pandas.
#
# This first entry describes the `.read_html()` function from the Pandas library.

# %%
pd.read_html?
episodes = pd.read_html(r'https://en.wikipedia.org/wiki/Parks_and_Recreation_%28season_3%29',header=0)
episodes
# also, uhoh...
# Out:
# [         Parks and Recreation (season 3)  \
#  0                          DVD cover art
#  1                               Starring
#  2                      Country of origin
#  3                        No. of episodes
#  4                                Release
#  5                       Original network
#  6                       Original release
#  7                      Season chronology
#  8    ← Previous Season 2 Next → Season 4
#  9  List of Parks and Recreation episodes
#
#                                            Unnamed: 1
#  0                                                NaN
#  1  Amy Poehler Rashida Jones Aziz Ansari Nick Off...
#  2                                      United States
#  3                                                 16
#  4                                                NaN
#  5                                                NBC
#  6  January 20 (2011-01-20) – May 19, 2011 (2011-0...
#  7                                                NaN
#  8                                                NaN
#  9                                                NaN  ,
#                                            No. overall  No. in season  \
#  0                                                  31            1.0
#  1   Leslie (Amy Poehler) and the parks department ...            NaN
#  2                                                  32            2.0
#  3   Flu season strikes Pawnee, and Ann must care f...            NaN
#  4                                                  33            3.0
#  5   Leslie's plans to bury a time capsule in Pawne...            NaN
#  6                                                  34            4.0
#  7   Just as Ron and Wendy break up when Wendy deci...            NaN
#  8                                                  35            5.0
#  9   Leslie, Ben and Tom conduct a series of televi...            NaN
#  10                                                 36            6.0
#  11  Ron and Leslie head to Indianapolis to receive...            NaN
#  12                                                 37            7.0
#  13  The day of the harvest festival has arrived an...            NaN
#  14                                                 38            8.0
#  15  City manager Paul (Phil Reeves) suffers a mass...            NaN
#  16                                                 39            9.0
#  17  Andy and April invite all their friends and fa...            NaN
#  18                                                 40           10.0
#  19  Leslie is disappointed when she asks Ben out o...            NaN
#  20                                                 41           11.0
#  21  Feeling frustrated and powerless because of he...            NaN
#  22                                                 42           12.0
#  23  Linsday Carlisle Shay (Parker Posey), the park...            NaN
#  24                                                 43           13.0
#  25  A job opens up with the health department and ...            NaN
#  26                                                 44           14.0
#  27  Chris sends Leslie and Ben on an assignment to...            NaN
#  28                                                 45           15.0
#  29  Leslie and Ben are reveling in "the bubble", t...            NaN
#  30                                                 46           16.0
#  31  Pawnee's favorite miniature horse, Li'l Sebast...            NaN
#
#                               Title        Directed by  \
#  0              "Go Big or Go Home"       Dean Holland
#  1                              NaN                NaN
#  2                     "Flu Season"    Wendey Stanzler
#  3                              NaN                NaN
#  4                   "Time Capsule"      Michael Schur
#  5                              NaN                NaN
#  6          "Ron & Tammy: Part Two"       Tucker Gates
#  7                              NaN                NaN
#  8                    "Media Blitz"       David Rogers
#  9                              NaN                NaN
#  10                  "Indianapolis"    Randall Einhorn
#  11                             NaN                NaN
#  12             "Harvest Festival"†       Dean Holland
#  13                             NaN                NaN
#  14                       "Camping"         Rob Schrab
#  15                             NaN                NaN
#  16  "Andy and April's Fancy Party"       Michael Trim
#  17                             NaN                NaN
#  18                     "Soulmates"    Ken Whittingham
#  19                             NaN                NaN
#  20             "Jerry's Painting"†       Dean Holland
#  21                             NaN                NaN
#  22                      "Eagleton"  Nicole Holofcener
#  23                             NaN                NaN
#  24                    "The Fight"†    Randall Einhorn
#  25                             NaN                NaN
#  26                     "Road Trip"        Troy Miller
#  27                             NaN                NaN
#  28                    "The Bubble"          Matt Sohn
#  29                             NaN                NaN
#  30               "Li'l Sebastian"†       Dean Holland
#  31                             NaN                NaN
#
#                    Written by               Original air date  \
#  0                  Alan Yang   January 20, 2011 (2011-01-20)
#  1                        NaN                             NaN
#  2               Norm Hiscock   January 27, 2011 (2011-01-27)
#  3                        NaN                             NaN
#  4              Michael Schur   February 3, 2011 (2011-02-03)
#  5                        NaN                             NaN
#  6               Emily Kapnek  February 10, 2011 (2011-02-10)
#  7                        NaN                             NaN
#  8             Harris Wittels  February 17, 2011 (2011-02-17)
#  9                        NaN                             NaN
#  10             Katie Dippold  February 24, 2011 (2011-02-24)
#  11                       NaN                             NaN
#  12                  Dan Goor     March 17, 2011 (2011-03-17)
#  13                       NaN                             NaN
#  14            Aisha Muharrar     March 24, 2011 (2011-03-24)
#  15                       NaN                             NaN
#  16             Katie Dippold     April 14, 2011 (2011-04-14)
#  17                       NaN                             NaN
#  18                 Alan Yang     April 21, 2011 (2011-04-21)
#  19                       NaN                             NaN
#  20              Norm Hiscock     April 28, 2011 (2011-04-28)
#  21                       NaN                             NaN
#  22              Emily Spivey        May 5, 2011 (2011-05-05)
#  23                       NaN                             NaN
#  24               Amy Poehler       May 12, 2011 (2011-05-12)
#  25                       NaN                             NaN
#  26            Harris Wittels       May 12, 2011 (2011-05-12)
#  27                       NaN                             NaN
#  28  Greg Levine & Brian Rowe       May 19, 2011 (2011-05-19)
#  29                       NaN                             NaN
#  30                  Dan Goor       May 19, 2011 (2011-05-19)
#  31                       NaN                             NaN
#
#     U.S. viewers (millions)
#  0                  6.14[1]
#  1                      NaN
#  2                  5.83[2]
#  3                      NaN
#  4                  4.95[3]
#  5                      NaN
#  6                  5.03[4]
#  7                      NaN
#  8                  4.33[5]
#  9                      NaN
#  10                 4.59[6]
#  11                     NaN
#  12                 4.08[7]
#  13                     NaN
#  14                 5.15[8]
#  15                     NaN
#  16                 5.16[9]
#  17                     NaN
#  18                4.88[10]
#  19                     NaN
#  20                4.71[11]
#  21                     NaN
#  22                5.06[12]
#  23                     NaN
#  24                4.55[13]
#  25                     NaN
#  26                3.54[13]
#  27                     NaN
#  28                4.27[14]
#  29                     NaN
#  30                3.72[14]
#  31                     NaN  ,
#    v t e Parks and Recreation  \
#  0                   Episodes
#  1                   Season 1
#  2                   Season 2
#  3                   Season 3
#  4                   Season 4
#  5                   Season 5
#  6                   Season 6
#  7                   Season 7
#  8                 Characters
#  9                    Related
#
#                                            Unnamed: 1 Unnamed: 2  \
#  0  Season 1 "Pilot" "Canvassing" "The Reporter" "...   Season 1
#  1  "Pilot" "Canvassing" "The Reporter" "Boys' Clu...        NaN
#  2  "Pawnee Zoo" "The Stakeout" "Beauty Pageant" "...        NaN
#  3  "Go Big or Go Home" "Flu Season" "Time Capsule...        NaN
#  4  "I'm Leslie Knope" "Ron and Tammys" "Born & Ra...        NaN
#  5  "Ms. Knope Goes to Washington" "Soda Tax" "How...        NaN
#  6                                                NaN        NaN
#  7                   "Leslie and Ron" "One Last Ride"        NaN
#  8  Leslie Knope Ron Swanson Tom Haverford Ann Per...        NaN
#  9                      Pawnee Awards and nominations        NaN
#
#                                            Unnamed: 3 Unnamed: 4  \
#  0  "Pilot" "Canvassing" "The Reporter" "Boys' Clu...   Season 2
#  1                                                NaN        NaN
#  2                                                NaN        NaN
#  3                                                NaN        NaN
#  4                                                NaN        NaN
#  5                                                NaN        NaN
#  6                                                NaN        NaN
#  7                                                NaN        NaN
#  8                                                NaN        NaN
#  9                                                NaN        NaN
#
#                                            Unnamed: 5 Unnamed: 6  \
#  0  "Pawnee Zoo" "The Stakeout" "Beauty Pageant" "...   Season 3
#  1                                                NaN        NaN
#  2                                                NaN        NaN
#  3                                                NaN        NaN
#  4                                                NaN        NaN
#  5                                                NaN        NaN
#  6                                                NaN        NaN
#  7                                                NaN        NaN
#  8                                                NaN        NaN
#  9                                                NaN        NaN
#
#                                            Unnamed: 7 Unnamed: 8  \
#  0  "Go Big or Go Home" "Flu Season" "Time Capsule...   Season 4
#  1                                                NaN        NaN
#  2                                                NaN        NaN
#  3                                                NaN        NaN
#  4                                                NaN        NaN
#  5                                                NaN        NaN
#  6                                                NaN        NaN
#  7                                                NaN        NaN
#  8                                                NaN        NaN
#  9                                                NaN        NaN
#
#                                            Unnamed: 9 Unnamed: 10  \
#  0  "I'm Leslie Knope" "Ron and Tammys" "Born & Ra...    Season 5
#  1                                                NaN         NaN
#  2                                                NaN         NaN
#  3                                                NaN         NaN
#  4                                                NaN         NaN
#  5                                                NaN         NaN
#  6                                                NaN         NaN
#  7                                                NaN         NaN
#  8                                                NaN         NaN
#  9                                                NaN         NaN
#
#                                           Unnamed: 11 Unnamed: 12  Unnamed: 13  \
#  0  "Ms. Knope Goes to Washington" "Soda Tax" "How...    Season 6          NaN
#  1                                                NaN         NaN          NaN
#  2                                                NaN         NaN          NaN
#  3                                                NaN         NaN          NaN
#  4                                                NaN         NaN          NaN
#  5                                                NaN         NaN          NaN
#  6                                                NaN         NaN          NaN
#  7                                                NaN         NaN          NaN
#  8                                                NaN         NaN          NaN
#  9                                                NaN         NaN          NaN
#
#    Unnamed: 14                       Unnamed: 15
#  0    Season 7  "Leslie and Ron" "One Last Ride"
#  1         NaN                               NaN
#  2         NaN                               NaN
#  3         NaN                               NaN
#  4         NaN                               NaN
#  5         NaN                               NaN
#  6         NaN                               NaN
#  7         NaN                               NaN
#  8         NaN                               NaN
#  9         NaN                               NaN  ,
#     Season 1  \
#  0  Season 2
#  1  Season 3
#  2  Season 4
#  3  Season 5
#  4  Season 6
#  5  Season 7
#
#    "Pilot" "Canvassing" "The Reporter" "Boys' Club" "The Banquet" "Rock Show"
#  0  "Pawnee Zoo" "The Stakeout" "Beauty Pageant" "...
#  1  "Go Big or Go Home" "Flu Season" "Time Capsule...
#  2  "I'm Leslie Knope" "Ron and Tammys" "Born & Ra...
#  3  "Ms. Knope Goes to Washington" "Soda Tax" "How...
#  4                                                NaN
#  5                   "Leslie and Ron" "One Last Ride"                          ]

# %% [markdown]
# Above, we've passed two arguments to the pd.read_html() method. First, we're passing the URL. Pandas will use other installed libraries to connect to this URL and begin extracting the tables as a list. Notice the '[' at the beginning, and the ']' all the way at the end? That should be an indication that it is a list.  Of course you could always:

# %%
type(episodes)
# Out:
# list

# %% [markdown]
# Since it is a list, it can be sliced. We just need to figure out which slice we want. Is it the first one? (remember, Python is zero-indexed.)

# %%
episodes[0]
# Out:
#          Parks and Recreation (season 3)  \
# 0                          DVD cover art
# 1                               Starring
# 2                      Country of origin
# 3                        No. of episodes
# 4                                Release
# 5                       Original network
# 6                       Original release
# 7                      Season chronology
# 8    ← Previous Season 2 Next → Season 4
# 9  List of Parks and Recreation episodes
#
#                                           Unnamed: 1
# 0                                                NaN
# 1  Amy Poehler Rashida Jones Aziz Ansari Nick Off...
# 2                                      United States
# 3                                                 16
# 4                                                NaN
# 5                                                NBC
# 6  January 20 (2011-01-20) – May 19, 2011 (2011-0...
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN

# %% [markdown]
# While we could do some things with this, this table isn't the full data we're looking to process. For this page, we're looking at the second table, or `episodes[1]`. We'll go ahead and assign that to a variable we're calling 'season'.

# %%
season = episodes[1]
season
# Out:
#                                           No. overall  No. in season  \
# 0                                                  31            1.0
# 1   Leslie (Amy Poehler) and the parks department ...            NaN
# 2                                                  32            2.0
# 3   Flu season strikes Pawnee, and Ann must care f...            NaN
# 4                                                  33            3.0
# 5   Leslie's plans to bury a time capsule in Pawne...            NaN
# 6                                                  34            4.0
# 7   Just as Ron and Wendy break up when Wendy deci...            NaN
# 8                                                  35            5.0
# 9   Leslie, Ben and Tom conduct a series of televi...            NaN
# 10                                                 36            6.0
# 11  Ron and Leslie head to Indianapolis to receive...            NaN
# 12                                                 37            7.0
# 13  The day of the harvest festival has arrived an...            NaN
# 14                                                 38            8.0
# 15  City manager Paul (Phil Reeves) suffers a mass...            NaN
# 16                                                 39            9.0
# 17  Andy and April invite all their friends and fa...            NaN
# 18                                                 40           10.0
# 19  Leslie is disappointed when she asks Ben out o...            NaN
# 20                                                 41           11.0
# 21  Feeling frustrated and powerless because of he...            NaN
# 22                                                 42           12.0
# 23  Linsday Carlisle Shay (Parker Posey), the park...            NaN
# 24                                                 43           13.0
# 25  A job opens up with the health department and ...            NaN
# 26                                                 44           14.0
# 27  Chris sends Leslie and Ben on an assignment to...            NaN
# 28                                                 45           15.0
# 29  Leslie and Ben are reveling in "the bubble", t...            NaN
# 30                                                 46           16.0
# 31  Pawnee's favorite miniature horse, Li'l Sebast...            NaN
#
#                              Title        Directed by  \
# 0              "Go Big or Go Home"       Dean Holland
# 1                              NaN                NaN
# 2                     "Flu Season"    Wendey Stanzler
# 3                              NaN                NaN
# 4                   "Time Capsule"      Michael Schur
# 5                              NaN                NaN
# 6          "Ron & Tammy: Part Two"       Tucker Gates
# 7                              NaN                NaN
# 8                    "Media Blitz"       David Rogers
# 9                              NaN                NaN
# 10                  "Indianapolis"    Randall Einhorn
# 11                             NaN                NaN
# 12             "Harvest Festival"†       Dean Holland
# 13                             NaN                NaN
# 14                       "Camping"         Rob Schrab
# 15                             NaN                NaN
# 16  "Andy and April's Fancy Party"       Michael Trim
# 17                             NaN                NaN
# 18                     "Soulmates"    Ken Whittingham
# 19                             NaN                NaN
# 20             "Jerry's Painting"†       Dean Holland
# 21                             NaN                NaN
# 22                      "Eagleton"  Nicole Holofcener
# 23                             NaN                NaN
# 24                    "The Fight"†    Randall Einhorn
# 25                             NaN                NaN
# 26                     "Road Trip"        Troy Miller
# 27                             NaN                NaN
# 28                    "The Bubble"          Matt Sohn
# 29                             NaN                NaN
# 30               "Li'l Sebastian"†       Dean Holland
# 31                             NaN                NaN
#
#                   Written by               Original air date  \
# 0                  Alan Yang   January 20, 2011 (2011-01-20)
# 1                        NaN                             NaN
# 2               Norm Hiscock   January 27, 2011 (2011-01-27)
# 3                        NaN                             NaN
# 4              Michael Schur   February 3, 2011 (2011-02-03)
# 5                        NaN                             NaN
# 6               Emily Kapnek  February 10, 2011 (2011-02-10)
# 7                        NaN                             NaN
# 8             Harris Wittels  February 17, 2011 (2011-02-17)
# 9                        NaN                             NaN
# 10             Katie Dippold  February 24, 2011 (2011-02-24)
# 11                       NaN                             NaN
# 12                  Dan Goor     March 17, 2011 (2011-03-17)
# 13                       NaN                             NaN
# 14            Aisha Muharrar     March 24, 2011 (2011-03-24)
# 15                       NaN                             NaN
# 16             Katie Dippold     April 14, 2011 (2011-04-14)
# 17                       NaN                             NaN
# 18                 Alan Yang     April 21, 2011 (2011-04-21)
# 19                       NaN                             NaN
# 20              Norm Hiscock     April 28, 2011 (2011-04-28)
# 21                       NaN                             NaN
# 22              Emily Spivey        May 5, 2011 (2011-05-05)
# 23                       NaN                             NaN
# 24               Amy Poehler       May 12, 2011 (2011-05-12)
# 25                       NaN                             NaN
# 26            Harris Wittels       May 12, 2011 (2011-05-12)
# 27                       NaN                             NaN
# 28  Greg Levine & Brian Rowe       May 19, 2011 (2011-05-19)
# 29                       NaN                             NaN
# 30                  Dan Goor       May 19, 2011 (2011-05-19)
# 31                       NaN                             NaN
#
#    U.S. viewers (millions)
# 0                  6.14[1]
# 1                      NaN
# 2                  5.83[2]
# 3                      NaN
# 4                  4.95[3]
# 5                      NaN
# 6                  5.03[4]
# 7                      NaN
# 8                  4.33[5]
# 9                      NaN
# 10                 4.59[6]
# 11                     NaN
# 12                 4.08[7]
# 13                     NaN
# 14                 5.15[8]
# 15                     NaN
# 16                 5.16[9]
# 17                     NaN
# 18                4.88[10]
# 19                     NaN
# 20                4.71[11]
# 21                     NaN
# 22                5.06[12]
# 23                     NaN
# 24                4.55[13]
# 25                     NaN
# 26                3.54[13]
# 27                     NaN
# 28                4.27[14]
# 29                     NaN
# 30                3.72[14]
# 31                     NaN

# %% [markdown]
# Notice here that there are a bunch of cells with 'NaN' in them. We talked about 'Not a Number' before, and again NumPy is saying that it couldn't find or interpret data here. We could use some Pandas functions to deal with these cells.

# %%
season.dropna()
# Out:
#    No. overall  No. in season                           Title  \
# 0           31            1.0             "Go Big or Go Home"
# 2           32            2.0                    "Flu Season"
# 4           33            3.0                  "Time Capsule"
# 6           34            4.0         "Ron & Tammy: Part Two"
# 8           35            5.0                   "Media Blitz"
# 10          36            6.0                  "Indianapolis"
# 12          37            7.0             "Harvest Festival"†
# 14          38            8.0                       "Camping"
# 16          39            9.0  "Andy and April's Fancy Party"
# 18          40           10.0                     "Soulmates"
# 20          41           11.0             "Jerry's Painting"†
# 22          42           12.0                      "Eagleton"
# 24          43           13.0                    "The Fight"†
# 26          44           14.0                     "Road Trip"
# 28          45           15.0                    "The Bubble"
# 30          46           16.0               "Li'l Sebastian"†
#
#           Directed by                Written by  \
# 0        Dean Holland                 Alan Yang
# 2     Wendey Stanzler              Norm Hiscock
# 4       Michael Schur             Michael Schur
# 6        Tucker Gates              Emily Kapnek
# 8        David Rogers            Harris Wittels
# 10    Randall Einhorn             Katie Dippold
# 12       Dean Holland                  Dan Goor
# 14         Rob Schrab            Aisha Muharrar
# 16       Michael Trim             Katie Dippold
# 18    Ken Whittingham                 Alan Yang
# 20       Dean Holland              Norm Hiscock
# 22  Nicole Holofcener              Emily Spivey
# 24    Randall Einhorn               Amy Poehler
# 26        Troy Miller            Harris Wittels
# 28          Matt Sohn  Greg Levine & Brian Rowe
# 30       Dean Holland                  Dan Goor
#
#                  Original air date U.S. viewers (millions)
# 0    January 20, 2011 (2011-01-20)                 6.14[1]
# 2    January 27, 2011 (2011-01-27)                 5.83[2]
# 4    February 3, 2011 (2011-02-03)                 4.95[3]
# 6   February 10, 2011 (2011-02-10)                 5.03[4]
# 8   February 17, 2011 (2011-02-17)                 4.33[5]
# 10  February 24, 2011 (2011-02-24)                 4.59[6]
# 12     March 17, 2011 (2011-03-17)                 4.08[7]
# 14     March 24, 2011 (2011-03-24)                 5.15[8]
# 16     April 14, 2011 (2011-04-14)                 5.16[9]
# 18     April 21, 2011 (2011-04-21)                4.88[10]
# 20     April 28, 2011 (2011-04-28)                4.71[11]
# 22        May 5, 2011 (2011-05-05)                5.06[12]
# 24       May 12, 2011 (2011-05-12)                4.55[13]
# 26       May 12, 2011 (2011-05-12)                3.54[13]
# 28       May 19, 2011 (2011-05-19)                4.27[14]
# 30       May 19, 2011 (2011-05-19)                3.72[14]

# %% [markdown]
# The .dropna() method effectively drops any rows where there are one or more NaN entries. Unfortunately, while the rows were mostly NaN, there were some cells with data in them. By default, .dropna() has the argument **how='any'**. Meaning, if a row contains one or more NaN, then .dropna() will drop it. Instead, we can use .dropna(how='all'). This will only drop rows where all cells are NaN.

# %%
season.dropna(how='all')
# Out:
#                                           No. overall  No. in season  \
# 0                                                  31            1.0
# 1   Leslie (Amy Poehler) and the parks department ...            NaN
# 2                                                  32            2.0
# 3   Flu season strikes Pawnee, and Ann must care f...            NaN
# 4                                                  33            3.0
# 5   Leslie's plans to bury a time capsule in Pawne...            NaN
# 6                                                  34            4.0
# 7   Just as Ron and Wendy break up when Wendy deci...            NaN
# 8                                                  35            5.0
# 9   Leslie, Ben and Tom conduct a series of televi...            NaN
# 10                                                 36            6.0
# 11  Ron and Leslie head to Indianapolis to receive...            NaN
# 12                                                 37            7.0
# 13  The day of the harvest festival has arrived an...            NaN
# 14                                                 38            8.0
# 15  City manager Paul (Phil Reeves) suffers a mass...            NaN
# 16                                                 39            9.0
# 17  Andy and April invite all their friends and fa...            NaN
# 18                                                 40           10.0
# 19  Leslie is disappointed when she asks Ben out o...            NaN
# 20                                                 41           11.0
# 21  Feeling frustrated and powerless because of he...            NaN
# 22                                                 42           12.0
# 23  Linsday Carlisle Shay (Parker Posey), the park...            NaN
# 24                                                 43           13.0
# 25  A job opens up with the health department and ...            NaN
# 26                                                 44           14.0
# 27  Chris sends Leslie and Ben on an assignment to...            NaN
# 28                                                 45           15.0
# 29  Leslie and Ben are reveling in "the bubble", t...            NaN
# 30                                                 46           16.0
# 31  Pawnee's favorite miniature horse, Li'l Sebast...            NaN
#
#                              Title        Directed by  \
# 0              "Go Big or Go Home"       Dean Holland
# 1                              NaN                NaN
# 2                     "Flu Season"    Wendey Stanzler
# 3                              NaN                NaN
# 4                   "Time Capsule"      Michael Schur
# 5                              NaN                NaN
# 6          "Ron & Tammy: Part Two"       Tucker Gates
# 7                              NaN                NaN
# 8                    "Media Blitz"       David Rogers
# 9                              NaN                NaN
# 10                  "Indianapolis"    Randall Einhorn
# 11                             NaN                NaN
# 12             "Harvest Festival"†       Dean Holland
# 13                             NaN                NaN
# 14                       "Camping"         Rob Schrab
# 15                             NaN                NaN
# 16  "Andy and April's Fancy Party"       Michael Trim
# 17                             NaN                NaN
# 18                     "Soulmates"    Ken Whittingham
# 19                             NaN                NaN
# 20             "Jerry's Painting"†       Dean Holland
# 21                             NaN                NaN
# 22                      "Eagleton"  Nicole Holofcener
# 23                             NaN                NaN
# 24                    "The Fight"†    Randall Einhorn
# 25                             NaN                NaN
# 26                     "Road Trip"        Troy Miller
# 27                             NaN                NaN
# 28                    "The Bubble"          Matt Sohn
# 29                             NaN                NaN
# 30               "Li'l Sebastian"†       Dean Holland
# 31                             NaN                NaN
#
#                   Written by               Original air date  \
# 0                  Alan Yang   January 20, 2011 (2011-01-20)
# 1                        NaN                             NaN
# 2               Norm Hiscock   January 27, 2011 (2011-01-27)
# 3                        NaN                             NaN
# 4              Michael Schur   February 3, 2011 (2011-02-03)
# 5                        NaN                             NaN
# 6               Emily Kapnek  February 10, 2011 (2011-02-10)
# 7                        NaN                             NaN
# 8             Harris Wittels  February 17, 2011 (2011-02-17)
# 9                        NaN                             NaN
# 10             Katie Dippold  February 24, 2011 (2011-02-24)
# 11                       NaN                             NaN
# 12                  Dan Goor     March 17, 2011 (2011-03-17)
# 13                       NaN                             NaN
# 14            Aisha Muharrar     March 24, 2011 (2011-03-24)
# 15                       NaN                             NaN
# 16             Katie Dippold     April 14, 2011 (2011-04-14)
# 17                       NaN                             NaN
# 18                 Alan Yang     April 21, 2011 (2011-04-21)
# 19                       NaN                             NaN
# 20              Norm Hiscock     April 28, 2011 (2011-04-28)
# 21                       NaN                             NaN
# 22              Emily Spivey        May 5, 2011 (2011-05-05)
# 23                       NaN                             NaN
# 24               Amy Poehler       May 12, 2011 (2011-05-12)
# 25                       NaN                             NaN
# 26            Harris Wittels       May 12, 2011 (2011-05-12)
# 27                       NaN                             NaN
# 28  Greg Levine & Brian Rowe       May 19, 2011 (2011-05-19)
# 29                       NaN                             NaN
# 30                  Dan Goor       May 19, 2011 (2011-05-19)
# 31                       NaN                             NaN
#
#    U.S. viewers (millions)
# 0                  6.14[1]
# 1                      NaN
# 2                  5.83[2]
# 3                      NaN
# 4                  4.95[3]
# 5                      NaN
# 6                  5.03[4]
# 7                      NaN
# 8                  4.33[5]
# 9                      NaN
# 10                 4.59[6]
# 11                     NaN
# 12                 4.08[7]
# 13                     NaN
# 14                 5.15[8]
# 15                     NaN
# 16                 5.16[9]
# 17                     NaN
# 18                4.88[10]
# 19                     NaN
# 20                4.71[11]
# 21                     NaN
# 22                5.06[12]
# 23                     NaN
# 24                4.55[13]
# 25                     NaN
# 26                3.54[13]
# 27                     NaN
# 28                4.27[14]
# 29                     NaN
# 30                3.72[14]
# 31                     NaN

# %% [markdown]
# This doesn't show anything here, as we don't have any rows that are completely filled with NaN. But, we can use .fillna() to automatically change that value to something else that may be relevant to your data collection methods.

# %%
season.fillna(-999)
# Out:
#                                           No. overall  No. in season  \
# 0                                                  31            1.0
# 1   Leslie (Amy Poehler) and the parks department ...         -999.0
# 2                                                  32            2.0
# 3   Flu season strikes Pawnee, and Ann must care f...         -999.0
# 4                                                  33            3.0
# 5   Leslie's plans to bury a time capsule in Pawne...         -999.0
# 6                                                  34            4.0
# 7   Just as Ron and Wendy break up when Wendy deci...         -999.0
# 8                                                  35            5.0
# 9   Leslie, Ben and Tom conduct a series of televi...         -999.0
# 10                                                 36            6.0
# 11  Ron and Leslie head to Indianapolis to receive...         -999.0
# 12                                                 37            7.0
# 13  The day of the harvest festival has arrived an...         -999.0
# 14                                                 38            8.0
# 15  City manager Paul (Phil Reeves) suffers a mass...         -999.0
# 16                                                 39            9.0
# 17  Andy and April invite all their friends and fa...         -999.0
# 18                                                 40           10.0
# 19  Leslie is disappointed when she asks Ben out o...         -999.0
# 20                                                 41           11.0
# 21  Feeling frustrated and powerless because of he...         -999.0
# 22                                                 42           12.0
# 23  Linsday Carlisle Shay (Parker Posey), the park...         -999.0
# 24                                                 43           13.0
# 25  A job opens up with the health department and ...         -999.0
# 26                                                 44           14.0
# 27  Chris sends Leslie and Ben on an assignment to...         -999.0
# 28                                                 45           15.0
# 29  Leslie and Ben are reveling in "the bubble", t...         -999.0
# 30                                                 46           16.0
# 31  Pawnee's favorite miniature horse, Li'l Sebast...         -999.0
#
#                              Title        Directed by  \
# 0              "Go Big or Go Home"       Dean Holland
# 1                             -999               -999
# 2                     "Flu Season"    Wendey Stanzler
# 3                             -999               -999
# 4                   "Time Capsule"      Michael Schur
# 5                             -999               -999
# 6          "Ron & Tammy: Part Two"       Tucker Gates
# 7                             -999               -999
# 8                    "Media Blitz"       David Rogers
# 9                             -999               -999
# 10                  "Indianapolis"    Randall Einhorn
# 11                            -999               -999
# 12             "Harvest Festival"†       Dean Holland
# 13                            -999               -999
# 14                       "Camping"         Rob Schrab
# 15                            -999               -999
# 16  "Andy and April's Fancy Party"       Michael Trim
# 17                            -999               -999
# 18                     "Soulmates"    Ken Whittingham
# 19                            -999               -999
# 20             "Jerry's Painting"†       Dean Holland
# 21                            -999               -999
# 22                      "Eagleton"  Nicole Holofcener
# 23                            -999               -999
# 24                    "The Fight"†    Randall Einhorn
# 25                            -999               -999
# 26                     "Road Trip"        Troy Miller
# 27                            -999               -999
# 28                    "The Bubble"          Matt Sohn
# 29                            -999               -999
# 30               "Li'l Sebastian"†       Dean Holland
# 31                            -999               -999
#
#                   Written by               Original air date  \
# 0                  Alan Yang   January 20, 2011 (2011-01-20)
# 1                       -999                            -999
# 2               Norm Hiscock   January 27, 2011 (2011-01-27)
# 3                       -999                            -999
# 4              Michael Schur   February 3, 2011 (2011-02-03)
# 5                       -999                            -999
# 6               Emily Kapnek  February 10, 2011 (2011-02-10)
# 7                       -999                            -999
# 8             Harris Wittels  February 17, 2011 (2011-02-17)
# 9                       -999                            -999
# 10             Katie Dippold  February 24, 2011 (2011-02-24)
# 11                      -999                            -999
# 12                  Dan Goor     March 17, 2011 (2011-03-17)
# 13                      -999                            -999
# 14            Aisha Muharrar     March 24, 2011 (2011-03-24)
# 15                      -999                            -999
# 16             Katie Dippold     April 14, 2011 (2011-04-14)
# 17                      -999                            -999
# 18                 Alan Yang     April 21, 2011 (2011-04-21)
# 19                      -999                            -999
# 20              Norm Hiscock     April 28, 2011 (2011-04-28)
# 21                      -999                            -999
# 22              Emily Spivey        May 5, 2011 (2011-05-05)
# 23                      -999                            -999
# 24               Amy Poehler       May 12, 2011 (2011-05-12)
# 25                      -999                            -999
# 26            Harris Wittels       May 12, 2011 (2011-05-12)
# 27                      -999                            -999
# 28  Greg Levine & Brian Rowe       May 19, 2011 (2011-05-19)
# 29                      -999                            -999
# 30                  Dan Goor       May 19, 2011 (2011-05-19)
# 31                      -999                            -999
#
#    U.S. viewers (millions)
# 0                  6.14[1]
# 1                     -999
# 2                  5.83[2]
# 3                     -999
# 4                  4.95[3]
# 5                     -999
# 6                  5.03[4]
# 7                     -999
# 8                  4.33[5]
# 9                     -999
# 10                 4.59[6]
# 11                    -999
# 12                 4.08[7]
# 13                    -999
# 14                 5.15[8]
# 15                    -999
# 16                 5.16[9]
# 17                    -999
# 18                4.88[10]
# 19                    -999
# 20                4.71[11]
# 21                    -999
# 22                5.06[12]
# 23                    -999
# 24                4.55[13]
# 25                    -999
# 26                3.54[13]
# 27                    -999
# 28                4.27[14]
# 29                    -999
# 30                3.72[14]
# 31                    -999

# %% [markdown]
# .fillna() has multiple methods, like forward fill, backward fill, interpolation.

# %%
# season.fillna?

# %%
season.fillna(method='ffill')
# Out:
#                                           No. overall  No. in season  \
# 0                                                  31            1.0
# 1   Leslie (Amy Poehler) and the parks department ...            1.0
# 2                                                  32            2.0
# 3   Flu season strikes Pawnee, and Ann must care f...            2.0
# 4                                                  33            3.0
# 5   Leslie's plans to bury a time capsule in Pawne...            3.0
# 6                                                  34            4.0
# 7   Just as Ron and Wendy break up when Wendy deci...            4.0
# 8                                                  35            5.0
# 9   Leslie, Ben and Tom conduct a series of televi...            5.0
# 10                                                 36            6.0
# 11  Ron and Leslie head to Indianapolis to receive...            6.0
# 12                                                 37            7.0
# 13  The day of the harvest festival has arrived an...            7.0
# 14                                                 38            8.0
# 15  City manager Paul (Phil Reeves) suffers a mass...            8.0
# 16                                                 39            9.0
# 17  Andy and April invite all their friends and fa...            9.0
# 18                                                 40           10.0
# 19  Leslie is disappointed when she asks Ben out o...           10.0
# 20                                                 41           11.0
# 21  Feeling frustrated and powerless because of he...           11.0
# 22                                                 42           12.0
# 23  Linsday Carlisle Shay (Parker Posey), the park...           12.0
# 24                                                 43           13.0
# 25  A job opens up with the health department and ...           13.0
# 26                                                 44           14.0
# 27  Chris sends Leslie and Ben on an assignment to...           14.0
# 28                                                 45           15.0
# 29  Leslie and Ben are reveling in "the bubble", t...           15.0
# 30                                                 46           16.0
# 31  Pawnee's favorite miniature horse, Li'l Sebast...           16.0
#
#                              Title        Directed by  \
# 0              "Go Big or Go Home"       Dean Holland
# 1              "Go Big or Go Home"       Dean Holland
# 2                     "Flu Season"    Wendey Stanzler
# 3                     "Flu Season"    Wendey Stanzler
# 4                   "Time Capsule"      Michael Schur
# 5                   "Time Capsule"      Michael Schur
# 6          "Ron & Tammy: Part Two"       Tucker Gates
# 7          "Ron & Tammy: Part Two"       Tucker Gates
# 8                    "Media Blitz"       David Rogers
# 9                    "Media Blitz"       David Rogers
# 10                  "Indianapolis"    Randall Einhorn
# 11                  "Indianapolis"    Randall Einhorn
# 12             "Harvest Festival"†       Dean Holland
# 13             "Harvest Festival"†       Dean Holland
# 14                       "Camping"         Rob Schrab
# 15                       "Camping"         Rob Schrab
# 16  "Andy and April's Fancy Party"       Michael Trim
# 17  "Andy and April's Fancy Party"       Michael Trim
# 18                     "Soulmates"    Ken Whittingham
# 19                     "Soulmates"    Ken Whittingham
# 20             "Jerry's Painting"†       Dean Holland
# 21             "Jerry's Painting"†       Dean Holland
# 22                      "Eagleton"  Nicole Holofcener
# 23                      "Eagleton"  Nicole Holofcener
# 24                    "The Fight"†    Randall Einhorn
# 25                    "The Fight"†    Randall Einhorn
# 26                     "Road Trip"        Troy Miller
# 27                     "Road Trip"        Troy Miller
# 28                    "The Bubble"          Matt Sohn
# 29                    "The Bubble"          Matt Sohn
# 30               "Li'l Sebastian"†       Dean Holland
# 31               "Li'l Sebastian"†       Dean Holland
#
#                   Written by               Original air date  \
# 0                  Alan Yang   January 20, 2011 (2011-01-20)
# 1                  Alan Yang   January 20, 2011 (2011-01-20)
# 2               Norm Hiscock   January 27, 2011 (2011-01-27)
# 3               Norm Hiscock   January 27, 2011 (2011-01-27)
# 4              Michael Schur   February 3, 2011 (2011-02-03)
# 5              Michael Schur   February 3, 2011 (2011-02-03)
# 6               Emily Kapnek  February 10, 2011 (2011-02-10)
# 7               Emily Kapnek  February 10, 2011 (2011-02-10)
# 8             Harris Wittels  February 17, 2011 (2011-02-17)
# 9             Harris Wittels  February 17, 2011 (2011-02-17)
# 10             Katie Dippold  February 24, 2011 (2011-02-24)
# 11             Katie Dippold  February 24, 2011 (2011-02-24)
# 12                  Dan Goor     March 17, 2011 (2011-03-17)
# 13                  Dan Goor     March 17, 2011 (2011-03-17)
# 14            Aisha Muharrar     March 24, 2011 (2011-03-24)
# 15            Aisha Muharrar     March 24, 2011 (2011-03-24)
# 16             Katie Dippold     April 14, 2011 (2011-04-14)
# 17             Katie Dippold     April 14, 2011 (2011-04-14)
# 18                 Alan Yang     April 21, 2011 (2011-04-21)
# 19                 Alan Yang     April 21, 2011 (2011-04-21)
# 20              Norm Hiscock     April 28, 2011 (2011-04-28)
# 21              Norm Hiscock     April 28, 2011 (2011-04-28)
# 22              Emily Spivey        May 5, 2011 (2011-05-05)
# 23              Emily Spivey        May 5, 2011 (2011-05-05)
# 24               Amy Poehler       May 12, 2011 (2011-05-12)
# 25               Amy Poehler       May 12, 2011 (2011-05-12)
# 26            Harris Wittels       May 12, 2011 (2011-05-12)
# 27            Harris Wittels       May 12, 2011 (2011-05-12)
# 28  Greg Levine & Brian Rowe       May 19, 2011 (2011-05-19)
# 29  Greg Levine & Brian Rowe       May 19, 2011 (2011-05-19)
# 30                  Dan Goor       May 19, 2011 (2011-05-19)
# 31                  Dan Goor       May 19, 2011 (2011-05-19)
#
#    U.S. viewers (millions)
# 0                  6.14[1]
# 1                  6.14[1]
# 2                  5.83[2]
# 3                  5.83[2]
# 4                  4.95[3]
# 5                  4.95[3]
# 6                  5.03[4]
# 7                  5.03[4]
# 8                  4.33[5]
# 9                  4.33[5]
# 10                 4.59[6]
# 11                 4.59[6]
# 12                 4.08[7]
# 13                 4.08[7]
# 14                 5.15[8]
# 15                 5.15[8]
# 16                 5.16[9]
# 17                 5.16[9]
# 18                4.88[10]
# 19                4.88[10]
# 20                4.71[11]
# 21                4.71[11]
# 22                5.06[12]
# 23                5.06[12]
# 24                4.55[13]
# 25                4.55[13]
# 26                3.54[13]
# 27                3.54[13]
# 28                4.27[14]
# 29                4.27[14]
# 30                3.72[14]
# 31                3.72[14]

# %% [markdown]
# while .fillna() is useful, the information contained in surrounding cells isn't that useful to us. It appears that in the case of this table, the first row (row 0) and each alternating row has information about the episode, and the second row (row 1) and each alternating row has the episode description of the previous episode. How do we deal with that? Slices, of course!

# %%
season[1::2]
# Out:
#                                           No. overall  No. in season Title  \
# 1   Leslie (Amy Poehler) and the parks department ...            NaN   NaN
# 3   Flu season strikes Pawnee, and Ann must care f...            NaN   NaN
# 5   Leslie's plans to bury a time capsule in Pawne...            NaN   NaN
# 7   Just as Ron and Wendy break up when Wendy deci...            NaN   NaN
# 9   Leslie, Ben and Tom conduct a series of televi...            NaN   NaN
# 11  Ron and Leslie head to Indianapolis to receive...            NaN   NaN
# 13  The day of the harvest festival has arrived an...            NaN   NaN
# 15  City manager Paul (Phil Reeves) suffers a mass...            NaN   NaN
# 17  Andy and April invite all their friends and fa...            NaN   NaN
# 19  Leslie is disappointed when she asks Ben out o...            NaN   NaN
# 21  Feeling frustrated and powerless because of he...            NaN   NaN
# 23  Linsday Carlisle Shay (Parker Posey), the park...            NaN   NaN
# 25  A job opens up with the health department and ...            NaN   NaN
# 27  Chris sends Leslie and Ben on an assignment to...            NaN   NaN
# 29  Leslie and Ben are reveling in "the bubble", t...            NaN   NaN
# 31  Pawnee's favorite miniature horse, Li'l Sebast...            NaN   NaN
#
#    Directed by Written by Original air date U.S. viewers (millions)
# 1          NaN        NaN               NaN                     NaN
# 3          NaN        NaN               NaN                     NaN
# 5          NaN        NaN               NaN                     NaN
# 7          NaN        NaN               NaN                     NaN
# 9          NaN        NaN               NaN                     NaN
# 11         NaN        NaN               NaN                     NaN
# 13         NaN        NaN               NaN                     NaN
# 15         NaN        NaN               NaN                     NaN
# 17         NaN        NaN               NaN                     NaN
# 19         NaN        NaN               NaN                     NaN
# 21         NaN        NaN               NaN                     NaN
# 23         NaN        NaN               NaN                     NaN
# 25         NaN        NaN               NaN                     NaN
# 27         NaN        NaN               NaN                     NaN
# 29         NaN        NaN               NaN                     NaN
# 31         NaN        NaN               NaN                     NaN

# %% [markdown]
# These slices will get us the descriptions alone, but we have a bunch of extra cells that are NaN, and irrelevant. Let's drop those using the indexers.

# %%
season[1::2].iloc[:,0]
# Out:
# 1     Leslie (Amy Poehler) and the parks department ...
# 3     Flu season strikes Pawnee, and Ann must care f...
# 5     Leslie's plans to bury a time capsule in Pawne...
# 7     Just as Ron and Wendy break up when Wendy deci...
# 9     Leslie, Ben and Tom conduct a series of televi...
# 11    Ron and Leslie head to Indianapolis to receive...
# 13    The day of the harvest festival has arrived an...
# 15    City manager Paul (Phil Reeves) suffers a mass...
# 17    Andy and April invite all their friends and fa...
# 19    Leslie is disappointed when she asks Ben out o...
# 21    Feeling frustrated and powerless because of he...
# 23    Linsday Carlisle Shay (Parker Posey), the park...
# 25    A job opens up with the health department and ...
# 27    Chris sends Leslie and Ben on an assignment to...
# 29    Leslie and Ben are reveling in "the bubble", t...
# 31    Pawnee's favorite miniature horse, Li'l Sebast...
# Name: No. overall, dtype: object

# %% [markdown]
# Pandas really wants to maintain the indices, which is usually really helpful - it helps prevent data mismatches down the road. But, what if we really want to ignore the index? We can reset it.

# %%
season[1::2].iloc[:,0].reset_index()
# Out:
#     index                                        No. overall
# 0       1  Leslie (Amy Poehler) and the parks department ...
# 1       3  Flu season strikes Pawnee, and Ann must care f...
# 2       5  Leslie's plans to bury a time capsule in Pawne...
# 3       7  Just as Ron and Wendy break up when Wendy deci...
# 4       9  Leslie, Ben and Tom conduct a series of televi...
# 5      11  Ron and Leslie head to Indianapolis to receive...
# 6      13  The day of the harvest festival has arrived an...
# 7      15  City manager Paul (Phil Reeves) suffers a mass...
# 8      17  Andy and April invite all their friends and fa...
# 9      19  Leslie is disappointed when she asks Ben out o...
# 10     21  Feeling frustrated and powerless because of he...
# 11     23  Linsday Carlisle Shay (Parker Posey), the park...
# 12     25  A job opens up with the health department and ...
# 13     27  Chris sends Leslie and Ben on an assignment to...
# 14     29  Leslie and Ben are reveling in "the bubble", t...
# 15     31  Pawnee's favorite miniature horse, Li'l Sebast...

# %% [markdown]
# Here we have created a new index, but Pandas (trying to save us from ourselves) has kept the index values from before, but in a separate Series within the new DataFrame. All we have to do now is drop it. While we're at it, let's go ahead and create an episode description variable and set it equal to this new series.

# %%
episode_desc = season[1::2].iloc[:,0].reset_index().drop('index',axis=1)
episode_desc
# Out:
#                                           No. overall
# 0   Leslie (Amy Poehler) and the parks department ...
# 1   Flu season strikes Pawnee, and Ann must care f...
# 2   Leslie's plans to bury a time capsule in Pawne...
# 3   Just as Ron and Wendy break up when Wendy deci...
# 4   Leslie, Ben and Tom conduct a series of televi...
# 5   Ron and Leslie head to Indianapolis to receive...
# 6   The day of the harvest festival has arrived an...
# 7   City manager Paul (Phil Reeves) suffers a mass...
# 8   Andy and April invite all their friends and fa...
# 9   Leslie is disappointed when she asks Ben out o...
# 10  Feeling frustrated and powerless because of he...
# 11  Linsday Carlisle Shay (Parker Posey), the park...
# 12  A job opens up with the health department and ...
# 13  Chris sends Leslie and Ben on an assignment to...
# 14  Leslie and Ben are reveling in "the bubble", t...
# 15  Pawnee's favorite miniature horse, Li'l Sebast...

# %% [markdown]
# The column name (No. Overall) doesn't make any sense, so we'll use the `.rename()` method to rename the columns using a dictionary with a single key-value pair.

# %%
episode_desc = episode_desc.rename(columns = {'No. overall':'Description'})
episode_desc
# Out:
#                                           Description
# 0   Leslie (Amy Poehler) and the parks department ...
# 1   Flu season strikes Pawnee, and Ann must care f...
# 2   Leslie's plans to bury a time capsule in Pawne...
# 3   Just as Ron and Wendy break up when Wendy deci...
# 4   Leslie, Ben and Tom conduct a series of televi...
# 5   Ron and Leslie head to Indianapolis to receive...
# 6   The day of the harvest festival has arrived an...
# 7   City manager Paul (Phil Reeves) suffers a mass...
# 8   Andy and April invite all their friends and fa...
# 9   Leslie is disappointed when she asks Ben out o...
# 10  Feeling frustrated and powerless because of he...
# 11  Linsday Carlisle Shay (Parker Posey), the park...
# 12  A job opens up with the health department and ...
# 13  Chris sends Leslie and Ben on an assignment to...
# 14  Leslie and Ben are reveling in "the bubble", t...
# 15  Pawnee's favorite miniature horse, Li'l Sebast...

# %% [markdown]
# For the other cells in the season dataframe, we want to start at the first row (row 0) and alternate getting all of the ones with the data. Since the procedure will be almost exactly the same as before, we'll skip ahead to the final part.

# %%
episode_data = season[0::2].reset_index().drop('index',axis=1)
episode_data
# Out:
#    No. overall  No. in season                           Title  \
# 0           31            1.0             "Go Big or Go Home"
# 1           32            2.0                    "Flu Season"
# 2           33            3.0                  "Time Capsule"
# 3           34            4.0         "Ron & Tammy: Part Two"
# 4           35            5.0                   "Media Blitz"
# 5           36            6.0                  "Indianapolis"
# 6           37            7.0             "Harvest Festival"†
# 7           38            8.0                       "Camping"
# 8           39            9.0  "Andy and April's Fancy Party"
# 9           40           10.0                     "Soulmates"
# 10          41           11.0             "Jerry's Painting"†
# 11          42           12.0                      "Eagleton"
# 12          43           13.0                    "The Fight"†
# 13          44           14.0                     "Road Trip"
# 14          45           15.0                    "The Bubble"
# 15          46           16.0               "Li'l Sebastian"†
#
#           Directed by                Written by  \
# 0        Dean Holland                 Alan Yang
# 1     Wendey Stanzler              Norm Hiscock
# 2       Michael Schur             Michael Schur
# 3        Tucker Gates              Emily Kapnek
# 4        David Rogers            Harris Wittels
# 5     Randall Einhorn             Katie Dippold
# 6        Dean Holland                  Dan Goor
# 7          Rob Schrab            Aisha Muharrar
# 8        Michael Trim             Katie Dippold
# 9     Ken Whittingham                 Alan Yang
# 10       Dean Holland              Norm Hiscock
# 11  Nicole Holofcener              Emily Spivey
# 12    Randall Einhorn               Amy Poehler
# 13        Troy Miller            Harris Wittels
# 14          Matt Sohn  Greg Levine & Brian Rowe
# 15       Dean Holland                  Dan Goor
#
#                  Original air date U.S. viewers (millions)
# 0    January 20, 2011 (2011-01-20)                 6.14[1]
# 1    January 27, 2011 (2011-01-27)                 5.83[2]
# 2    February 3, 2011 (2011-02-03)                 4.95[3]
# 3   February 10, 2011 (2011-02-10)                 5.03[4]
# 4   February 17, 2011 (2011-02-17)                 4.33[5]
# 5   February 24, 2011 (2011-02-24)                 4.59[6]
# 6      March 17, 2011 (2011-03-17)                 4.08[7]
# 7      March 24, 2011 (2011-03-24)                 5.15[8]
# 8      April 14, 2011 (2011-04-14)                 5.16[9]
# 9      April 21, 2011 (2011-04-21)                4.88[10]
# 10     April 28, 2011 (2011-04-28)                4.71[11]
# 11        May 5, 2011 (2011-05-05)                5.06[12]
# 12       May 12, 2011 (2011-05-12)                4.55[13]
# 13       May 12, 2011 (2011-05-12)                3.54[13]
# 14       May 19, 2011 (2011-05-19)                4.27[14]
# 15       May 19, 2011 (2011-05-19)                3.72[14]

# %% [markdown]
# Now we have a list of data and a list of descriptions. By wonderful coincidence (not really), they both have the same number of cells. Let's check to be certain.

# %% [markdown]
# aside: programming languages are funny about the equals sign '='. A lot of times, we want to see if something is equal to something else. Python assumes that a single equals means that you are **making a thing equal to some other thing**.
#
# If you want to check to see if two entities *are equal* then you will use the double equal '=='
#
# single = 'is'
#
# `age = 5`
#
# age _is_ 5
#
# double == 'is it'
#
# `age == 5`
#
# age, _is it_ 5?
#
# this is a largely semantic discussion, but you would be surprised how often it causes problems.

# %%
len(episode_data) == len(episode_desc)
# Out:
# True

# %% [markdown]
# Now, let's concatenate the data DataFrame, and the description Series. Remember to specify axis.

# %%
episode_list = pd.concat([episode_data,episode_desc],axis=1)

# %% [markdown]
# Checking the column heads just to be certain.

# %%
episode_list.columns
# Out:
# Index([            u'No. overall',           u'No. in season',
#                          u'Title',             u'Directed by',
#                     u'Written by',       u'Original air date',
#        u'U.S. viewers (millions)',             u'Description'],
#       dtype='object')

# %% [markdown]
# Setting the index to one of the unique Series in the DataFrame. 'No. Overall' makes sense.

# %%
episode_list = episode_list.set_index('No. overall')

# %%
episode_list
# Out:
#              No. in season                           Title        Directed by  \
# No. overall
# 31                     1.0             "Go Big or Go Home"       Dean Holland
# 32                     2.0                    "Flu Season"    Wendey Stanzler
# 33                     3.0                  "Time Capsule"      Michael Schur
# 34                     4.0         "Ron & Tammy: Part Two"       Tucker Gates
# 35                     5.0                   "Media Blitz"       David Rogers
# 36                     6.0                  "Indianapolis"    Randall Einhorn
# 37                     7.0             "Harvest Festival"†       Dean Holland
# 38                     8.0                       "Camping"         Rob Schrab
# 39                     9.0  "Andy and April's Fancy Party"       Michael Trim
# 40                    10.0                     "Soulmates"    Ken Whittingham
# 41                    11.0             "Jerry's Painting"†       Dean Holland
# 42                    12.0                      "Eagleton"  Nicole Holofcener
# 43                    13.0                    "The Fight"†    Randall Einhorn
# 44                    14.0                     "Road Trip"        Troy Miller
# 45                    15.0                    "The Bubble"          Matt Sohn
# 46                    16.0               "Li'l Sebastian"†       Dean Holland
#
#                            Written by               Original air date  \
# No. overall
# 31                          Alan Yang   January 20, 2011 (2011-01-20)
# 32                       Norm Hiscock   January 27, 2011 (2011-01-27)
# 33                      Michael Schur   February 3, 2011 (2011-02-03)
# 34                       Emily Kapnek  February 10, 2011 (2011-02-10)
# 35                     Harris Wittels  February 17, 2011 (2011-02-17)
# 36                      Katie Dippold  February 24, 2011 (2011-02-24)
# 37                           Dan Goor     March 17, 2011 (2011-03-17)
# 38                     Aisha Muharrar     March 24, 2011 (2011-03-24)
# 39                      Katie Dippold     April 14, 2011 (2011-04-14)
# 40                          Alan Yang     April 21, 2011 (2011-04-21)
# 41                       Norm Hiscock     April 28, 2011 (2011-04-28)
# 42                       Emily Spivey        May 5, 2011 (2011-05-05)
# 43                        Amy Poehler       May 12, 2011 (2011-05-12)
# 44                     Harris Wittels       May 12, 2011 (2011-05-12)
# 45           Greg Levine & Brian Rowe       May 19, 2011 (2011-05-19)
# 46                           Dan Goor       May 19, 2011 (2011-05-19)
#
#             U.S. viewers (millions)  \
# No. overall
# 31                          6.14[1]
# 32                          5.83[2]
# 33                          4.95[3]
# 34                          5.03[4]
# 35                          4.33[5]
# 36                          4.59[6]
# 37                          4.08[7]
# 38                          5.15[8]
# 39                          5.16[9]
# 40                         4.88[10]
# 41                         4.71[11]
# 42                         5.06[12]
# 43                         4.55[13]
# 44                         3.54[13]
# 45                         4.27[14]
# 46                         3.72[14]
#
#                                                    Description
# No. overall
# 31           Leslie (Amy Poehler) and the parks department ...
# 32           Flu season strikes Pawnee, and Ann must care f...
# 33           Leslie's plans to bury a time capsule in Pawne...
# 34           Just as Ron and Wendy break up when Wendy deci...
# 35           Leslie, Ben and Tom conduct a series of televi...
# 36           Ron and Leslie head to Indianapolis to receive...
# 37           The day of the harvest festival has arrived an...
# 38           City manager Paul (Phil Reeves) suffers a mass...
# 39           Andy and April invite all their friends and fa...
# 40           Leslie is disappointed when she asks Ben out o...
# 41           Feeling frustrated and powerless because of he...
# 42           Linsday Carlisle Shay (Parker Posey), the park...
# 43           A job opens up with the health department and ...
# 44           Chris sends Leslie and Ben on an assignment to...
# 45           Leslie and Ben are reveling in "the bubble", t...
# 46           Pawnee's favorite miniature horse, Li'l Sebast...

# %% [markdown]
# For the sake of space, the preview here doesn't show all the information, but you can definitely check the contents by using the `.values` property.

# %%
episode_list['Description'].values
# Out:
# array([ u"Leslie (Amy Poehler) and the parks department return to work after three months, only to be told by state auditors Chris (Rob Lowe) and Ben (Adam Scott) that the budget crisis still looms. After unsuccessfully trying to have their budget restored by using Ann (Rashida Jones) to seduce Chris with a date, Leslie decides to make an all or nothing play by resurrecting the Pawnee harvest festival. Either the festival is a financial success, or the parks Department will be eliminated. After their bad date, Ann apologizes to Chris and asks to go out again, and he accepts. Meanwhile, Ben restarts the youth basketball league and instates Ron (Nick Offerman) and Andy (Chris Pratt) to coach the only two teams. Tom (Aziz Ansari) referees, but gives preferental treatment to Andy out of jealousy that Ron is dating Tom's ex-wife, Wendy (Jama Williamson). April, still angry with Andy for having kissed Ann, returns from a vacation with a new boyfriend from Venezuela, Eduardo. A disappointed Andy vows to win her back.",
#        u"Flu season strikes Pawnee, and Ann must care for the flu victims at the hospital, which include April, Leslie, and Chris. While April tries to make life hard for Ann as revenge for kissing Andy, Ron needs an assistant to fill in for April and selects Andy, whom he bonds with over the Colts, lunch, and playing football in the parking lot. Ann finds out Leslie stole April and Chris' flu medicine to go make her speech to convince business owners to donate items for the Harvest Festival with Ben, who tries to get her to return to the hospital. However to Ben and Tom's surprise, Leslie makes a flawless speech. Tom tries to squirm out of working on the speech to go hot tubbing at a club, which they discover is essential, since the three old guys he hot tubs with own car dealerships and they've offered to donate cars for the festival. Ann must care for Chris, who is so healthy, his immune system and 2.8% body fat makes him very weak and prone to disease. Ironically, Chris gets the flu and is bedridden to the joy of Ann. Chris recovers and asks Ben if he should prolong their stay in Pawnee instead of returning to Indianapolis. They decide to prolong their stay.",
#        u"Leslie's plans to bury a time capsule in Pawnee are derailed when local man Kelly (Will Forte) chains himself to a pipe in Leslie's office because she refuses to include the Twilight novel in the capsule. Eventually Leslie holds a public forum to decide what will go in the capsule, but it grows quickly out of control when the Pawnee citizens cannot agree on what it should include. Leslie resolves the matter by including nothing but a video-recording of the meeting, which she feels captures Pawnee by showing the passion of its citizens. Meanwhile, Andy gets help from Chris in winning back April, which makes Ann worry that Andy will once again interfere in her relationship. Tom laments that his girlfriend Lucy (Natalie Morales) has broken up with him, and she reveals she left Tom because he cannot get over his jealousy of Ron and Wendy.",
#        u"Just as Ron and Wendy break up when Wendy decides to move back to Canada, Ron's ex-wife Tammy (Megan Mullally) returns to try to make Ron's life miserable. Tom, still angry about Ron dating Wendy, brings Tammy to a date to make Ron jealous. Instead, Ron and Tammy reconnect and end up remarrying each other in the middle of a night of drinking and wild sex that leaves them both in prison. Leslie asks Pawnee police Chief Hugh Trumple (Eric Pierpoint) to release Ron as a favor, even though the favor she originally planned to ask was for the police to volunteer officers for security as the harvest festival. Later, Ben asks the chief for that favor as well, and he agrees out of respect for Leslie. Tom tries to stop Ron from proceeding with Tammy, which causes Tammy to beat him senseless. Realizing Tammy is still a horrible woman, Ron breaks up with her. Meanwhile, April fills in as Chris' assistant and, impressed with her, he asks April to work with him in Indianapolis, much to the chagrin of Ann and Andy.",
#        u"Leslie, Ben and Tom conduct a series of television, radio and newspaper interviews to promote the harvest festival. However, during one interview, Ben is confronted about his past as an 18-year-old mayor, during which he made his city go bankrupt. The socially awkward Ben struggles to respond to these questions, and the story becomes increasingly about him rather than the harvest festival. With Leslie's encouragement, however, Ben finds his confidence and insists his mistakes are in the past, which steers the coverage back to the festival. Meanwhile, Andy struggles to do everything April hates with the hopes of stopping her from moving to Indianapolis. After Ron encourages April to stop stringing Andy along, she finally forgives Andy and kisses him. Meanwhile, Ann and Chris agree they must sort out the future of their relationship before moving back to Indianapolis.",
#        u'Ron and Leslie head to Indianapolis to receive a commendation for reviving the harvest festival. Before they leave, Ann confides in Leslie that she thinks Chris might be cheating on her. Leslie searches Chris\' house for clues, which prompts Ann to come to Indianapolis herself to confront Chris. However, Ann is humiliated to learn Chris previously broke up with her, but did so in such a positive way that she did not realize it. Meanwhile, Tom and Ben bond at a club where Tom hopes to pitch his cologne, "Tommy Fresh", to fragrance mogul Dennis Feinstein (Jason Mantzoukas). Ben comforts Tom after Feinstein rejects and insults Tom\'s fragrance. Meanwhile, at the same bar, April and Andy compete to see who can win the most free stuff.',
#        u'The day of the harvest festival has arrived and everything seems to be going well. However, when a local Native American tribe leader (Jonathan Joss) gets angry the festival is over an Indian burial site, the local press becomes fixated on the story of a supposed Native American curse on the festival. To make matters worse, Li\'l Sebastian, Pawnee\'s beloved celebrity miniature horse goes missing on Tom\'s watch. The bad press risks keeping visitors away from the festival, but things get straightened out when Li\'l Sebastian is found and Leslie makes peace with the tribe leader. Meanwhile, April tells Andy she loves him, but is displeased when Andy replies, "Awesome-sauce!" instead of "I love you." She later learns, however, that this is Andy\'s way of expressing love.',
#        u"City manager Paul (Phil Reeves) suffers a massive heart attack, and Chris returns from Indianapolis to serve as acting city manager. Fresh off her harvest festival success, Leslie takes the parks department (along with Ann) on a camping trip to brainstorm ideas for their next big project. April is less than enthused about having to be out in the open and recruits Andy to keep her entertained, but he gets lost in the wilderness. Tom and Ben equip their tent with Tom's luxury and electronic items from Sky Mall, the powering of which drains the battery on the van and leaves the crew stranded. They seek refuge at a nearby bed and breakfast, where Leslie laments that she has no ideas for their next project and is worrying that she is a one-hit wonder. Ron solves her problem by forcing her to have a good night's sleep and she awakens fresh with numerous big-project ideas.",
#        u'Andy and April invite all their friends and family to a dinner party, which turns out to be their secret wedding. Fearing they are moving too fast, Leslie tries to stop it, but Ron assures her that Andy and April need to make their own decisions. Tom is thrilled to be named best man, but is discouraged when he learns Andy has several "best men". Ben debates whether or not to return to his old job or take a job offered to him by Chris in Pawnee. Leslie encourages him to stay, which he does. Meanwhile, Ann attends a singles mixer but acts awkwardly until she receives dating advice from Donna (Retta).',
#        u"Leslie is disappointed when she asks Ben out on a date and he turns her down. Ann convinces her to sign up with an online dating service, but the website surprisingly matches Leslie up with Tom. Determined to find out why they are supposedly a match, Leslie takes Tom out to lunch, which proves to be disastrous. Tom relentlessly teases Leslie and reveals he has multiple accounts at the site with the hopes of attracting all types of women. Leslie is later relieved to learn Ben only turned her down because Chris has a strict policy against office relationships. Meanwhile, Chris tries to impose a health initiative in Pawnee, which starts by banning red meat from the cafeteria. To prevent this, Ron challenges Chris to a cook-off between Chris' lean turkey burgers and Ron's traditional hamburger, the latter of which ends up the winner.",
#        u"Feeling frustrated and powerless because of her situation with Ben, Leslie finds strength in a painting Jerry (Jim O'Heir) contributes to a community art show, which depicts her as a powerful and bare-chested Greek goddess. The painting immediately causes a stir and prompts calls for it to be destroyed, which Leslie emphatically protests. Tom supports destruction of the painting, which depicts him as a pot-bellied cherub. Ben gets tired of living in a hotel and moves in with April and Andy, only to discover the place is filthy and they do not know how to take care of themselves. He resolves to teach them how to be adults, which April initially resists because she does not want to lose her individuality. Leslie eventually swaps the painting with a duplicate Jerry makes, that depicts Tom as the Greek god, and allows Leslie to keep the empowering portrait.",
#        u"Linsday Carlisle Shay (Parker Posey), the parks director from the prosperous neighboring city of Eagleton, antagonizes her former best friend Leslie by building a large fence to divide a park within both city limits. Leslie appeals the decision to an Eagleton public forum, but the rich and snobbish residents agree with the fence due to their distaste for Pawnee. After getting into a garbage fight with Lindsay that lands them both in jail, Leslie turns the situation into a positive one by assembling a wiffle ball team that makes use of the fence. Meanwhile, Leslie has found out it is Ron's birthday, a fact that he went to extreme lengths to conceal, and Leslie plans a party against his wishes. However, she surprises him by throwing not a huge birthday bash, but an appropriate one for Ron: time alone with steak, whiskey and his favorite movies.",
#        u'A job opens up with the health department and Leslie immediately recommends Ann, who is unenthusiastic about having to leave her nursing job and the amount of prep work there is for the interview the next day. When the parks department comes out to the Snakehole Lounge bar for the debut of Tom\'s new drink "Snake Juice", Leslie sees that Ann has blown off her preparation work to go out dancing. The two get in their first major fight, while everyone else gets extremely drunk from Tom\'s drink. The next day, with Ben\'s help, a regretful Ann and Leslie make amends, and Ann receives the part-time city hall job. Meanwhile, Chris forces Tom to sell his shares in the Snakehole Lounge because it conflicts with his government job, much to Tom\'s disappointment.',
#        u"Chris sends Leslie and Ben on an assignment to Indianapolis, and Leslie is unsure she can keep from acting on her feelings for Ben in such close quarters. The assignment proves a success and Leslie and Ben appear on the verge of getting together, but Chris surprises them by showing up to celebrate their success. Although Chris' constant interruptions spoil the mood, Leslie and Ben secretly kiss each other after getting back to Pawnee. Meanwhile, Tom invents a new game show entitled Know Ya Boo, a rip-off of The Newlywed Game, and tests it out on April, Andy, Donna and Jerry. The game causes a big fight when April reveals she likes another band more than Andy's, and April reluctantly seeks advice from Ann about how to make amends with him. April ends the fight and proves her appreciation for Andy by performing one of his songs in city hall.",
#        u'Leslie and Ben are reveling in "the bubble", the beginning stage of a relationship when everything is simple and fun. That is threatened, however, when Leslie\'s notoriously tough mother Marlene (Pamela Reed), a Pawnee politician, meets with Ben to discuss a business request. Leslie initially makes Ben nervous for the meeting and Marlene believes him to be weak. When Leslie tries to prepare him for a follow-up meeting, Ben is so confident that Marlene ends up becoming attracted to him herself. Fed up, Ben admits he is secretly dating Leslie, much to Marlene\'s amusement. Meanwhile, Chris instigates changes to the parks department, that include making Tom work on city hall\'s dreaded "fourth floor", which frustrates him. The changes prove counter-productive, and Ron approaches Chris with a compromise that puts almost everything back to normal.',
#        u"Pawnee's favorite miniature horse, Li'l Sebastian, dies and the parks department organizes a memorial service. The extremely health-conscious Chris learns he has tendonitis and takes it very badly, but is comforted by Ann. Leslie and Ben have trouble keeping their relationship secret, and their efforts to do so causes problems with Li'l Sebastian's eternal flame that nearly kill Ron with a fireball. Tom and his friend Jean-Ralphio successfully organize Li'l Sebastian's service, and Andy comes up with an amazing memorial song. Tom finally hands in his letter of resignation to Ron, who sadly accepts it and bids farewell to him. After the service, Ron is taunted by his ex-wife Tammy, but both are horrified to learn his first ex-wife, also named Tammy, has arrived in town. Leslie is approached to possibly consider running for elected office, but when asked about any potential scandals, she neglects to admit to her secret affair with Ben."], dtype=object)

# %% [markdown]
# Indexers can be used like slices. They have the brackets and colons, but they can also be used in conjunction with commas to indicate two dimensions. In the first example, we use our knowledge of slices on a DataFrame to separate content out in two different ways. We're also using the NumPy `.all()` method to verify that the two sections are equivalent. We can also check the number of entries by using the `.len()` method.

# %%
print np.all(season[1::2].iloc[:,0] == season.iloc[1::2,0])
print len(season[1::2].iloc[:,0])
print len(season.iloc[1::2,0])
# Out:
# True
# 16
# 16

# %%
episode_list.iloc[2:20,1:4]
# Out:
#                                       Title        Directed by  \
# No. overall
# 33                           "Time Capsule"      Michael Schur
# 34                  "Ron & Tammy: Part Two"       Tucker Gates
# 35                            "Media Blitz"       David Rogers
# 36                           "Indianapolis"    Randall Einhorn
# 37                      "Harvest Festival"†       Dean Holland
# 38                                "Camping"         Rob Schrab
# 39           "Andy and April's Fancy Party"       Michael Trim
# 40                              "Soulmates"    Ken Whittingham
# 41                      "Jerry's Painting"†       Dean Holland
# 42                               "Eagleton"  Nicole Holofcener
# 43                             "The Fight"†    Randall Einhorn
# 44                              "Road Trip"        Troy Miller
# 45                             "The Bubble"          Matt Sohn
# 46                        "Li'l Sebastian"†       Dean Holland
#
#                            Written by
# No. overall
# 33                      Michael Schur
# 34                       Emily Kapnek
# 35                     Harris Wittels
# 36                      Katie Dippold
# 37                           Dan Goor
# 38                     Aisha Muharrar
# 39                      Katie Dippold
# 40                          Alan Yang
# 41                       Norm Hiscock
# 42                       Emily Spivey
# 43                        Amy Poehler
# 44                     Harris Wittels
# 45           Greg Levine & Brian Rowe
# 46                           Dan Goor

# %% [markdown]
# In fact, all of these are functionally equivalent:

# %%
# .loc uses strings to locate cells
episode_list.loc[:,'Title']

# .iloc uses integers to locate cells
episode_list.iloc[:,1] 

# .ix uses strings first, but can use integers if none are available. It's deprecated, so don't expect it to be here long.
#episode_list.ix[:,'Title']

#episode_list.ix[:,1]

# alternatively, you can refer to the specific column head
episode_list['Title']

# or use dot notation (if there are no spaces in the column head).
episode_list.Title
# Out:
# No. overall
# 31               "Go Big or Go Home"
# 32                      "Flu Season"
# 33                    "Time Capsule"
# 34           "Ron & Tammy: Part Two"
# 35                     "Media Blitz"
# 36                    "Indianapolis"
# 37               "Harvest Festival"†
# 38                         "Camping"
# 39    "Andy and April's Fancy Party"
# 40                       "Soulmates"
# 41               "Jerry's Painting"†
# 42                        "Eagleton"
# 43                      "The Fight"†
# 44                       "Road Trip"
# 45                      "The Bubble"
# 46                 "Li'l Sebastian"†
# Name: Title, dtype: object

# %%
episode_list
# Out:
#              No. in season                           Title        Directed by  \
# No. overall
# 31                     1.0             "Go Big or Go Home"       Dean Holland
# 32                     2.0                    "Flu Season"    Wendey Stanzler
# 33                     3.0                  "Time Capsule"      Michael Schur
# 34                     4.0         "Ron & Tammy: Part Two"       Tucker Gates
# 35                     5.0                   "Media Blitz"       David Rogers
# 36                     6.0                  "Indianapolis"    Randall Einhorn
# 37                     7.0             "Harvest Festival"†       Dean Holland
# 38                     8.0                       "Camping"         Rob Schrab
# 39                     9.0  "Andy and April's Fancy Party"       Michael Trim
# 40                    10.0                     "Soulmates"    Ken Whittingham
# 41                    11.0             "Jerry's Painting"†       Dean Holland
# 42                    12.0                      "Eagleton"  Nicole Holofcener
# 43                    13.0                    "The Fight"†    Randall Einhorn
# 44                    14.0                     "Road Trip"        Troy Miller
# 45                    15.0                    "The Bubble"          Matt Sohn
# 46                    16.0               "Li'l Sebastian"†       Dean Holland
#
#                            Written by               Original air date  \
# No. overall
# 31                          Alan Yang   January 20, 2011 (2011-01-20)
# 32                       Norm Hiscock   January 27, 2011 (2011-01-27)
# 33                      Michael Schur   February 3, 2011 (2011-02-03)
# 34                       Emily Kapnek  February 10, 2011 (2011-02-10)
# 35                     Harris Wittels  February 17, 2011 (2011-02-17)
# 36                      Katie Dippold  February 24, 2011 (2011-02-24)
# 37                           Dan Goor     March 17, 2011 (2011-03-17)
# 38                     Aisha Muharrar     March 24, 2011 (2011-03-24)
# 39                      Katie Dippold     April 14, 2011 (2011-04-14)
# 40                          Alan Yang     April 21, 2011 (2011-04-21)
# 41                       Norm Hiscock     April 28, 2011 (2011-04-28)
# 42                       Emily Spivey        May 5, 2011 (2011-05-05)
# 43                        Amy Poehler       May 12, 2011 (2011-05-12)
# 44                     Harris Wittels       May 12, 2011 (2011-05-12)
# 45           Greg Levine & Brian Rowe       May 19, 2011 (2011-05-19)
# 46                           Dan Goor       May 19, 2011 (2011-05-19)
#
#             U.S. viewers (millions)  \
# No. overall
# 31                          6.14[1]
# 32                          5.83[2]
# 33                          4.95[3]
# 34                          5.03[4]
# 35                          4.33[5]
# 36                          4.59[6]
# 37                          4.08[7]
# 38                          5.15[8]
# 39                          5.16[9]
# 40                         4.88[10]
# 41                         4.71[11]
# 42                         5.06[12]
# 43                         4.55[13]
# 44                         3.54[13]
# 45                         4.27[14]
# 46                         3.72[14]
#
#                                                    Description
# No. overall
# 31           Leslie (Amy Poehler) and the parks department ...
# 32           Flu season strikes Pawnee, and Ann must care f...
# 33           Leslie's plans to bury a time capsule in Pawne...
# 34           Just as Ron and Wendy break up when Wendy deci...
# 35           Leslie, Ben and Tom conduct a series of televi...
# 36           Ron and Leslie head to Indianapolis to receive...
# 37           The day of the harvest festival has arrived an...
# 38           City manager Paul (Phil Reeves) suffers a mass...
# 39           Andy and April invite all their friends and fa...
# 40           Leslie is disappointed when she asks Ben out o...
# 41           Feeling frustrated and powerless because of he...
# 42           Linsday Carlisle Shay (Parker Posey), the park...
# 43           A job opens up with the health department and ...
# 44           Chris sends Leslie and Ben on an assignment to...
# 45           Leslie and Ben are reveling in "the bubble", t...
# 46           Pawnee's favorite miniature horse, Li'l Sebast...

# %% [markdown]
# ###### REGEX TIME!

# %% [markdown]
# Now, we're going to use the .apply() method to apply a function to a column. We're going to convert the 'Original air date' column to a DateTime object. Pandas will try to see if there are ways to interpret the information in these cells as dates.

# %%
pd.to_datetime?

# %%
#episode_list['Original air date'] = episode_list['Original air date'].apply(pd.to_datetime)
# ignore this next line, for now.
episode_list['Original air date'] = episode_list['Original air date'].str.split("\D+").str[-4:-1].str.join('-')

# %% [markdown]
# looking at the bottom, you can see that the datatype is now a datetime64 object.

# %%
episode_list
# Out:
#              No. in season                           Title        Directed by  \
# No. overall
# 31                     1.0             "Go Big or Go Home"       Dean Holland
# 32                     2.0                    "Flu Season"    Wendey Stanzler
# 33                     3.0                  "Time Capsule"      Michael Schur
# 34                     4.0         "Ron & Tammy: Part Two"       Tucker Gates
# 35                     5.0                   "Media Blitz"       David Rogers
# 36                     6.0                  "Indianapolis"    Randall Einhorn
# 37                     7.0             "Harvest Festival"†       Dean Holland
# 38                     8.0                       "Camping"         Rob Schrab
# 39                     9.0  "Andy and April's Fancy Party"       Michael Trim
# 40                    10.0                     "Soulmates"    Ken Whittingham
# 41                    11.0             "Jerry's Painting"†       Dean Holland
# 42                    12.0                      "Eagleton"  Nicole Holofcener
# 43                    13.0                    "The Fight"†    Randall Einhorn
# 44                    14.0                     "Road Trip"        Troy Miller
# 45                    15.0                    "The Bubble"          Matt Sohn
# 46                    16.0               "Li'l Sebastian"†       Dean Holland
#
#                            Written by Original air date  \
# No. overall
# 31                          Alan Yang        2011-01-20
# 32                       Norm Hiscock        2011-01-27
# 33                      Michael Schur        2011-02-03
# 34                       Emily Kapnek        2011-02-10
# 35                     Harris Wittels        2011-02-17
# 36                      Katie Dippold        2011-02-24
# 37                           Dan Goor        2011-03-17
# 38                     Aisha Muharrar        2011-03-24
# 39                      Katie Dippold        2011-04-14
# 40                          Alan Yang        2011-04-21
# 41                       Norm Hiscock        2011-04-28
# 42                       Emily Spivey        2011-05-05
# 43                        Amy Poehler        2011-05-12
# 44                     Harris Wittels        2011-05-12
# 45           Greg Levine & Brian Rowe        2011-05-19
# 46                           Dan Goor        2011-05-19
#
#             U.S. viewers (millions)  \
# No. overall
# 31                          6.14[1]
# 32                          5.83[2]
# 33                          4.95[3]
# 34                          5.03[4]
# 35                          4.33[5]
# 36                          4.59[6]
# 37                          4.08[7]
# 38                          5.15[8]
# 39                          5.16[9]
# 40                         4.88[10]
# 41                         4.71[11]
# 42                         5.06[12]
# 43                         4.55[13]
# 44                         3.54[13]
# 45                         4.27[14]
# 46                         3.72[14]
#
#                                                    Description
# No. overall
# 31           Leslie (Amy Poehler) and the parks department ...
# 32           Flu season strikes Pawnee, and Ann must care f...
# 33           Leslie's plans to bury a time capsule in Pawne...
# 34           Just as Ron and Wendy break up when Wendy deci...
# 35           Leslie, Ben and Tom conduct a series of televi...
# 36           Ron and Leslie head to Indianapolis to receive...
# 37           The day of the harvest festival has arrived an...
# 38           City manager Paul (Phil Reeves) suffers a mass...
# 39           Andy and April invite all their friends and fa...
# 40           Leslie is disappointed when she asks Ben out o...
# 41           Feeling frustrated and powerless because of he...
# 42           Linsday Carlisle Shay (Parker Posey), the park...
# 43           A job opens up with the health department and ...
# 44           Chris sends Leslie and Ben on an assignment to...
# 45           Leslie and Ben are reveling in "the bubble", t...
# 46           Pawnee's favorite miniature horse, Li'l Sebast...

# %% [markdown]
# Looking at the viewer numbers, they are formatted like this:
#
# `4.70[19]`
#
# Unfortunately, Pandas doesn't know what to do with this; the format isn't anything it recognizes. So, we're going to temporarily convert it to a string, and use some string methods on it. Specifically, we'll use the `.split()` method again. This time, however, there isn't a space to _split_ on. As we mentioned before, the `.split()` method allows you to split on a specified character - we'll use the open bracket, as it separates the number from the footnote.

# %%
episode_list.ix[:,5].str.split('[')
# Out:
# No. overall
# 31     [6.14, 1]]
# 32     [5.83, 2]]
# 33     [4.95, 3]]
# 34     [5.03, 4]]
# 35     [4.33, 5]]
# 36     [4.59, 6]]
# 37     [4.08, 7]]
# 38     [5.15, 8]]
# 39     [5.16, 9]]
# 40    [4.88, 10]]
# 41    [4.71, 11]]
# 42    [5.06, 12]]
# 43    [4.55, 13]]
# 44    [3.54, 13]]
# 45    [4.27, 14]]
# 46    [3.72, 14]]
# Name: U.S. viewers (millions), dtype: object

# %% [markdown]
# The cells are each split into two values. The numbers before the '[', and everything else. We only care about the stuff in the front, so we'll grab it with (you guessed it) a slice. While we're at it, we're going to go ahead and convert everything to a float, so we can have a number with a decimal.

# %%
episode_list.ix[:,5] = episode_list.ix[:,5].str.split('[').str[0].astype('Float32')

# %%
episode_list.ix[:,5].median()
# Out:
# 4.795000076293945

# %% [markdown]
# Now, let's do some graphing!
#
# First, we'll tell jupyter that we want to do the graphs inline, and then we'll import another library.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# Graphing can be as simple as using the `.plot()` method.

# %%
episode_list.ix[:,5:7].plot();

# %% [markdown]
# But what if we want to get really fancy? PyPlot has some really excellent features. We can append this stuff to the default figure 1.

# %%
plt.plot?

# %%
print type(episode_list.ix[:,1])
print type(episode_list.ix[:,1].values)
# Out:
# <class 'pandas.core.series.Series'>
# <type 'numpy.ndarray'>

# %%
plt.xticks?

# %%
episode_titles = episode_list.ix[:,1].values
episode_viewers = episode_list.ix[:,5].values

index = np.arange(len(episode_list))

plt.figure(num=None, figsize=(16, 8), facecolor='w', edgecolor='k')
plt.plot(index, episode_viewers,'b')
plt.legend()
plt.plot(pd.Series(episode_viewers).rolling(window=3).mean(), 'r')
plt.ylabel('Viewers (in millions)')
plt.grid()
plt.xlabel('Episode Titles')
plt.title('Parks & Recreation Viewer Stats')
plt.xticks(index,episode_titles,rotation=90);
# Out:
# C:\Users\fbbigger\AppData\Local\Continuum\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
test_array = np.arange(36).reshape(6,6)

# %%
test_array[0][0]
# Out:
# 0

# %%
test_int = 7

# %%
test_int.real
# Out:
# 7
